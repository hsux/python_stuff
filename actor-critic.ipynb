# %% [markdown]
# https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/blob/master/contents/8_Actor_Critic_Advantage/AC_CartPole.py
#
# 结合了 Policy Gradient (Actor) 和 Function Approximation (Critic) 的方法. `Actor` 基于概率选行为, `Critic` 基于 `Actor` 的行为评判行为的得分, `Actor` 根据 `Critic` 的评分修改选行为的概率.
#
# **Actor Critic 方法的优势**: 可以进行单步更新, 比传统的 Policy Gradient 要快.
#
# **Actor Critic 方法的劣势**: 取决于 Critic 的价值判断, 但是 Critic 难收敛, 再加上 Actor 的更新, 就更难收敛. 为了解决收敛问题, Google Deepmind 提出了 `Actor Critic` 升级版 `Deep Deterministic Policy Gradient`. 后者融合了 DQN 的优势, 解决了收敛难的问题. 我们之后也会要讲到 Deep Deterministic Policy Gradient. 不过那个是要以 `Actor Critic` 为基础, 懂了 `Actor Critic`, 后面那个就好懂了.

# %%
import numpy as np
import tensorflow as tf
import gym

# %%
print(gym.__version__)
print(tf.__version__)
# Out:
# 0.17.2
# 1.15.0

# %%
np.random.seed(2)
tf.set_random_seed(2)  # reproducible

# Superparameters
OUTPUT_GRAPH = False
MAX_EPISODE = 1000
DISPLAY_REWARD_THRESHOLD = 200  # renders environment if total episode reward is greater then this threshold
MAX_EP_STEPS = 1000   # maximum time step in one episode
RENDER = False  # rendering wastes time
GAMMA = 0.9     # reward discount in TD error
LR_A = 0.001    # learning rate for actor
LR_C = 0.01     # learning rate for critic

env = gym.make('CartPole-v0')
env.seed(1)  # reproducible
env = env.unwrapped

N_F = env.observation_space.shape[0]
N_A = env.action_space.n

# %%
print(N_F)
print(N_A)
# Out:
# 4
# 2

# %% [markdown]
# `Actor` 想要最大化期望的 `reward`, 在 `Actor Critic` 算法中, 我们用 “比平时好多少” (`TD error`) 来当做 `reward`.
#
# `Actor` 在运用 Policy Gradient 的方法进行 Gradient ascent 的时候, 由 `Critic` 来告诉他, 这次的 Gradient ascent 是不是一次正确的 ascent, 如果这次的得分不好, 那么就不要 ascent 那么多.

# %%
# 基于概率选行为
class Actor(object):
    def __init__(self, sess, n_features, n_actions, lr=0.001):
        '''
        用tf建立actor网络，搭建训练的graph
        '''
        self.sess = sess

        self.s = tf.placeholder(tf.float32, [1, n_features], "state")
        self.a = tf.placeholder(tf.int32, None, "act")
        self.td_error = tf.placeholder(tf.float32, None, "td_error")  # TD_error

        with tf.variable_scope('Actor'):
            l1 = tf.layers.dense(
                inputs=self.s,
                units=20,    # number of hidden units
                activation=tf.nn.relu,
                kernel_initializer=tf.random_normal_initializer(0., .1),    # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l1'
            )

            self.acts_prob = tf.layers.dense(
                inputs=l1,
                units=n_actions,    # output units
                activation=tf.nn.softmax,   # get action probabilities
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='acts_prob'
            )

        with tf.variable_scope('exp_v'):
            log_prob = tf.log(self.acts_prob[0, self.a])
            self.exp_v = tf.reduce_mean(log_prob * self.td_error)  # advantage (TD_error) guided loss

        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(-self.exp_v)  # minimize(-exp_v) = maximize(exp_v)

    def learn(self, s, a, td):
        '''
        s,a产生gradient ascent的方向，td来自critic，告诉actor这个方向对不对
        '''
        s = s[np.newaxis, :]
        feed_dict = {self.s: s, self.a: a, self.td_error: td}
        _, exp_v = self.sess.run([self.train_op, self.exp_v], feed_dict)
        return exp_v

    def choose_action(self, s):
        '''
        根据s选择a
        '''
        s = s[np.newaxis, :]
        probs = self.sess.run(self.acts_prob, {self.s: s})   # get probabilities for all actions
        return np.random.choice(np.arange(probs.shape[1]), p=probs.ravel())   # return a int

# %% [markdown]
# `Critic` 的更新很简单, 就是像 Q learning 那样更新现实和估计的误差 (TD error) 就好了.

# %%
class Critic(object):
    def __init__(self, sess, n_features, lr=0.01):
        self.sess = sess

        self.s = tf.placeholder(tf.float32, [1, n_features], "state")
        self.v_ = tf.placeholder(tf.float32, [1, 1], "v_next")
        self.r = tf.placeholder(tf.float32, None, 'r')

        with tf.variable_scope('Critic'):
            l1 = tf.layers.dense(
                inputs=self.s,
                units=20,  # number of hidden units
                activation=tf.nn.relu,  # None
                # have to be linear to make sure the convergence of actor.
                # But linear approximator seems hardly learns the correct Q.
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='l1'
            )

            self.v = tf.layers.dense(
                inputs=l1,
                units=1,  # output units
                activation=None,
                kernel_initializer=tf.random_normal_initializer(0., .1),  # weights
                bias_initializer=tf.constant_initializer(0.1),  # biases
                name='V'
            )

        with tf.variable_scope('squared_TD_error'):
            # 立即奖励 + 衰减的动作后状态的潜在奖励衰减 - 动作前状态的奖励。
            self.td_error = self.r + GAMMA * self.v_ - self.v
            self.loss = tf.square(self.td_error)    # TD_error = (r+gamma*V_next) - V_eval
        with tf.variable_scope('train'):
            self.train_op = tf.train.AdamOptimizer(lr).minimize(self.loss)

    def learn(self, s, r, s_):
        s, s_ = s[np.newaxis, :], s_[np.newaxis, :]

        v_ = self.sess.run(self.v, {self.s: s_})
        td_error, _ = self.sess.run([self.td_error, self.train_op],
                                          {self.s: s, self.v_: v_, self.r: r})
        return td_error

# %% [markdown]
# 在 `Policy Gradients` 的影片中提到过, 现实中的奖惩会左右 `Actor` 的更新情况. `Policy Gradients` 也是靠着这个来获取适宜的更新. 那么何时会有奖惩这种信息能不能被学习呢? 这看起来不就是 以值为基础的强化学习方法做过的事吗. 那我们就拿一个 `Critic` 去学习这些奖惩机制, 学习完了以后由 `Actor` 来指手画脚,由 `Critic` 来告诉 `Actor` 你的那些指手画脚哪些指得好, 哪些指得差.
#
# `Critic` 通过学习环境和奖励之间的关系, 能看到现在所处状态`s_`的潜在奖励`v_`, 所以用它来指点 `Actor` 便能使 `Actor` 每一步都在更新, 如果使用单纯的 `Policy Gradients`, `Actor` 只能等到回合结束才能开始更新.

# %% [markdown]
# https://www.jianshu.com/p/25c09ae3d206
#
# `Actor`输入是一个状态，一个动作，一个奖惩；vt换成td_error；选择动作和Policy Gradient一样，根据计算出的softmax值来选择动作。
#
# `Critic`要反馈给`Actor`一个时间差分值`td_error`，来决定`Actor`选择动作的好坏，如果时间差分值大的话，说明当前`Actor`选择的这个动作的惊喜度较高，需要更多的出现来使得时间差分值减小。
# 考虑时间差分的计算：
# TD = r + gamma * f(s') - f(s),这里f(s)即`self.v`代表将`s`状态输入到`Critic`神经网络中得到的`Q`值。
# 所以`Critic`的输入也分三个，首先是当前状态`s`，当前的奖励`self.v`，以及下一个时刻的奖励折现值`self.v_`。为什么没有动作`a`呢？动作`a`是确定的呀，是`Actor`选的呀，对不对！还有为什么不是下一时刻的`Q`值而不是下一个时刻的状态，因为我们已经在计算`TD`时已经把状态带入到神经网络中得到`Q`值了。

# %%
sess = tf.Session()

# %%
actor = Actor(sess, n_features=N_F, n_actions=N_A, lr=LR_A)
critic = Critic(sess, n_features=N_F, lr=LR_C)     # we need a good teacher, so the teacher should learn faster than the actor

sess.run(tf.global_variables_initializer())
# Out:
# WARNING:tensorflow:From <ipython-input-4-f1396ae77d6e>:20: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From d:\python\anaconda3\envs\tf15\lib\site-packages\tensorflow_core\python\layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %%
if OUTPUT_GRAPH:
    tf.summary.FileWriter("logs/", sess.graph)

for i_episode in range(MAX_EPISODE):
    s = env.reset()
    t = 0
    track_r = []
    while True:
        if RENDER: env.render()

        a = actor.choose_action(s)

        s_, r, done, info = env.step(a)  # s_下一步状态,r立即奖励，done指示位，表示这一训练周期是否结束，True or False

        if done: r = -20

        track_r.append(r)
        
        # ac算法中把pg中的vt的手动计算，用critic网络代替
        td_error = critic.learn(s, r, s_)  # gradient = grad[r + gamma * V(s_) - V(s)]
        actor.learn(s, a, td_error)     # true_gradient = grad[logPi(s,a) * td_error]

        s = s_
        t += 1

        if done or t >= MAX_EP_STEPS:
            ep_rs_sum = sum(track_r)

            if 'running_reward' not in globals():
                running_reward = ep_rs_sum
            else:
                running_reward = running_reward * 0.95 + ep_rs_sum * 0.05
            if running_reward > DISPLAY_REWARD_THRESHOLD: RENDER = True  # rendering
            print("episode:", i_episode, "  reward:", int(running_reward))
            break
# Out:
# episode: 0   reward: -7
# episode: 1   reward: -6
# episode: 2   reward: -5
# episode: 3   reward: -5
# episode: 4   reward: -5
# episode: 5   reward: -5
# episode: 6   reward: -6
# episode: 7   reward: -6
# episode: 8   reward: -6
# episode: 9   reward: -6
# episode: 10   reward: -6
# episode: 11   reward: -6
# episode: 12   reward: -5
# episode: 13   reward: -5
# episode: 14   reward: -5
# episode: 15   reward: -5
# episode: 16   reward: -5
# episode: 17   reward: -5
# episode: 18   reward: -5
# episode: 19   reward: -4
# episode: 20   reward: -4
# episode: 21   reward: -3
# episode: 22   reward: -3
# episode: 23   reward: -3
# episode: 24   reward: -4
# episode: 25   reward: -3
# episode: 26   reward: -3
# episode: 27   reward: -4
# episode: 28   reward: -3
# episode: 29   reward: -3
# episode: 30   reward: -2
# episode: 31   reward: -2
# episode: 32   reward: -2
# episode: 33   reward: -1
# episode: 34   reward: -1
# episode: 35   reward: -2
# episode: 36   reward: -1
# episode: 37   reward: -2
# episode: 38   reward: 0
# episode: 39   reward: 0
# episode: 40   reward: 0
# episode: 41   reward: 0
# episode: 42   reward: 0
# episode: 43   reward: 0
# episode: 44   reward: 0
# episode: 45   reward: -1
# episode: 46   reward: -1
# episode: 47   reward: -1
# episode: 48   reward: -2
# episode: 49   reward: -2
# episode: 50   reward: -2
# episode: 51   reward: -2
# episode: 52   reward: -2
# episode: 53   reward: -1
# episode: 54   reward: 0
# episode: 55   reward: 1
# episode: 56   reward: 3
# episode: 57   reward: 5
# episode: 58   reward: 5
# episode: 59   reward: 7
# episode: 60   reward: 7
# episode: 61   reward: 7
# episode: 62   reward: 7
# episode: 63   reward: 6
# episode: 64   reward: 6
# episode: 65   reward: 7
# episode: 66   reward: 6
# episode: 67   reward: 5
# episode: 68   reward: 5
# episode: 69   reward: 6
# episode: 70   reward: 5
# episode: 71   reward: 5
# episode: 72   reward: 6
# episode: 73   reward: 6
# episode: 74   reward: 6
# episode: 75   reward: 5
# episode: 76   reward: 5
# episode: 77   reward: 5
# episode: 78   reward: 5
# episode: 79   reward: 7
# episode: 80   reward: 10
# episode: 81   reward: 9
# episode: 82   reward: 9
# episode: 83   reward: 9
# episode: 84   reward: 8
# episode: 85   reward: 8
# episode: 86   reward: 8
# episode: 87   reward: 8
# episode: 88   reward: 8
# episode: 89   reward: 8
# episode: 90   reward: 8
# episode: 91   reward: 7
# episode: 92   reward: 9
# episode: 93   reward: 9
# episode: 94   reward: 8
# episode: 95   reward: 8
# episode: 96   reward: 9
# episode: 97   reward: 10
# episode: 98   reward: 9
# episode: 99   reward: 9
# episode: 100   reward: 15
# episode: 101   reward: 15
# episode: 102   reward: 15
# episode: 103   reward: 15
# episode: 104   reward: 16
# episode: 105   reward: 17
# episode: 106   reward: 18
# episode: 107   reward: 17
# episode: 108   reward: 19
# episode: 109   reward: 19
# episode: 110   reward: 23
# episode: 111   reward: 23
# episode: 112   reward: 23
# episode: 113   reward: 24
# episode: 114   reward: 24
# episode: 115   reward: 24
# episode: 116   reward: 24
# episode: 117   reward: 25
# episode: 118   reward: 26
# episode: 119   reward: 27
# episode: 120   reward: 27
# episode: 121   reward: 28
# episode: 122   reward: 30
# episode: 123   reward: 30
# episode: 124   reward: 30
# episode: 125   reward: 29
# episode: 126   reward: 33
# episode: 127   reward: 34
# episode: 128   reward: 37
# episode: 129   reward: 43
# episode: 130   reward: 47
# episode: 131   reward: 51
# episode: 132   reward: 55
# episode: 133   reward: 65
# episode: 134   reward: 94
# episode: 135   reward: 99
# episode: 136   reward: 115
# episode: 137   reward: 121
# episode: 138   reward: 126
# episode: 139   reward: 158
# episode: 140   reward: 179
# episode: 141   reward: 172
# episode: 142   reward: 214
# episode: 143   reward: 228
# episode: 144   reward: 226
# episode: 145   reward: 222
# episode: 146   reward: 220
# episode: 147   reward: 221
# episode: 148   reward: 216
# episode: 149   reward: 211
# episode: 150   reward: 205
# episode: 151   reward: 195
# episode: 152   reward: 186
# episode: 153   reward: 176
# episode: 154   reward: 168
# episode: 155   reward: 162
# episode: 156   reward: 162
# episode: 157   reward: 178
# episode: 158   reward: 180
# episode: 159   reward: 181
# episode: 160   reward: 200
# episode: 161   reward: 212
# episode: 162   reward: 208
# episode: 163   reward: 202
# episode: 164   reward: 197
# episode: 165   reward: 191
# episode: 166   reward: 186
# episode: 167   reward: 182
# episode: 168   reward: 181
# episode: 169   reward: 180
# episode: 170   reward: 176
# episode: 171   reward: 173
# episode: 172   reward: 169
# episode: 173   reward: 166
# episode: 174   reward: 159
# episode: 175   reward: 156
# episode: 176   reward: 153
# episode: 177   reward: 150
# episode: 178   reward: 147
# episode: 179   reward: 147
# episode: 180   reward: 146
# episode: 181   reward: 145
# episode: 182   reward: 144
# episode: 183   reward: 144
# episode: 184   reward: 142
# episode: 185   reward: 142
# episode: 186   reward: 143
# episode: 187   reward: 142
# episode: 188   reward: 144
# episode: 189   reward: 146
# episode: 190   reward: 144
# episode: 191   reward: 141
# episode: 192   reward: 138
# episode: 193   reward: 131
# episode: 194   reward: 129
# episode: 195   reward: 124
# episode: 196   reward: 119
# episode: 197   reward: 114
# episode: 198   reward: 110
# episode: 199   reward: 104
# episode: 200   reward: 99
# episode: 201   reward: 95
# episode: 202   reward: 92
# episode: 203   reward: 88
# episode: 204   reward: 85
# episode: 205   reward: 82
# episode: 206   reward: 83
# episode: 207   reward: 82
# episode: 208   reward: 83
# episode: 209   reward: 85
# episode: 210   reward: 87
# episode: 211   reward: 91
# episode: 212   reward: 93
# episode: 213   reward: 103
# episode: 214   reward: 110
# episode: 215   reward: 109
# episode: 216   reward: 109
# episode: 217   reward: 113
# episode: 218   reward: 117
# episode: 219   reward: 120
# episode: 220   reward: 119
# episode: 221   reward: 121
# episode: 222   reward: 138
# episode: 223   reward: 142
# episode: 224   reward: 142
# episode: 225   reward: 140
# episode: 226   reward: 140
# episode: 227   reward: 140
# episode: 228   reward: 141
# episode: 229   reward: 141
# episode: 230   reward: 137
# episode: 231   reward: 136
# episode: 232   reward: 136
# episode: 233   reward: 137
# episode: 234   reward: 139
# episode: 235   reward: 162
# episode: 236   reward: 179
# episode: 237   reward: 185
# episode: 238   reward: 186
# episode: 239   reward: 184
# episode: 240   reward: 175
# episode: 241   reward: 166
# episode: 242   reward: 158
# episode: 243   reward: 150
# episode: 244   reward: 142
# episode: 245   reward: 151
# episode: 246   reward: 152
# episode: 247   reward: 145
# episode: 248   reward: 137
# episode: 249   reward: 130
# episode: 250   reward: 123
# episode: 251   reward: 117
# episode: 252   reward: 110
# episode: 253   reward: 104
# episode: 254   reward: 99
# episode: 255   reward: 93
# episode: 256   reward: 90
# episode: 257   reward: 85
# episode: 258   reward: 81
# episode: 259   reward: 77
# episode: 260   reward: 72
# episode: 261   reward: 68
# episode: 262   reward: 65
# episode: 263   reward: 61
# episode: 264   reward: 57
# episode: 265   reward: 54
# episode: 266   reward: 51
# episode: 267   reward: 48
# episode: 268   reward: 45
# episode: 269   reward: 42
# episode: 270   reward: 40
# episode: 271   reward: 38
# episode: 272   reward: 36
# episode: 273   reward: 36
# episode: 274   reward: 35
# episode: 275   reward: 42
# episode: 276   reward: 40
# episode: 277   reward: 39
# episode: 278   reward: 37
# episode: 279   reward: 35
# episode: 280   reward: 43
# episode: 281   reward: 49
# episode: 282   reward: 61
# episode: 283   reward: 58
# episode: 284   reward: 58
# episode: 285   reward: 59
# episode: 286   reward: 61
# episode: 287   reward: 66
# episode: 288   reward: 67
# episode: 289   reward: 71
# episode: 290   reward: 73
# episode: 291   reward: 80
# episode: 292   reward: 85
# episode: 293   reward: 85
# episode: 294   reward: 85
# episode: 295   reward: 84
# episode: 296   reward: 94
# episode: 297   reward: 90
# episode: 298   reward: 87
# episode: 299   reward: 89
# episode: 300   reward: 90
# episode: 301   reward: 88
# episode: 302   reward: 87
# episode: 303   reward: 86
# episode: 304   reward: 90
# episode: 305   reward: 88
# episode: 306   reward: 92
# episode: 307   reward: 88
# episode: 308   reward: 96
# episode: 309   reward: 94
# episode: 310   reward: 97
# episode: 311   reward: 97
# episode: 312   reward: 104
# episode: 313   reward: 118
# episode: 314   reward: 162
# episode: 315   reward: 169
# episode: 316   reward: 167
# episode: 317   reward: 164
# episode: 318   reward: 161
# episode: 319   reward: 158
# episode: 320   reward: 154
# episode: 321   reward: 151
# episode: 322   reward: 144
# episode: 323   reward: 141
# episode: 324   reward: 138
# episode: 325   reward: 133
# episode: 326   reward: 128
# episode: 327   reward: 126
# episode: 328   reward: 123
# episode: 329   reward: 119
# episode: 330   reward: 115
# episode: 331   reward: 115
# episode: 332   reward: 115
# episode: 333   reward: 115
# episode: 334   reward: 119
# episode: 335   reward: 120
# episode: 336   reward: 121
# episode: 337   reward: 136
# episode: 338   reward: 137
# episode: 339   reward: 144
# episode: 340   reward: 174
# episode: 341   reward: 215
# episode: 342   reward: 255
# episode: 343   reward: 292
# episode: 344   reward: 327
# episode: 345   reward: 331
# episode: 346   reward: 364
# episode: 347   reward: 396
# episode: 348   reward: 426
# episode: 349   reward: 424
# episode: 350   reward: 453
# episode: 351   reward: 480
# episode: 352   reward: 481
# episode: 353   reward: 464
# episode: 354   reward: 444
# episode: 355   reward: 422
# episode: 356   reward: 401
# episode: 357   reward: 381
# episode: 358   reward: 363
# episode: 359   reward: 344
# episode: 360   reward: 327
# episode: 361   reward: 312
# episode: 362   reward: 296
# episode: 363   reward: 282
# episode: 364   reward: 268
# episode: 365   reward: 255
# episode: 366   reward: 242
# episode: 367   reward: 230
# episode: 368   reward: 219
# episode: 369   reward: 208
# episode: 370   reward: 199
# episode: 371   reward: 189
# episode: 372   reward: 181
# episode: 373   reward: 172
# episode: 374   reward: 164
# episode: 375   reward: 157
# episode: 376   reward: 149
# episode: 377   reward: 143
# episode: 378   reward: 136
# episode: 379   reward: 129
# episode: 380   reward: 123
# episode: 381   reward: 117
# episode: 382   reward: 111
# episode: 383   reward: 106
# episode: 384   reward: 101
# episode: 385   reward: 96
# episode: 386   reward: 92
# episode: 387   reward: 87
# episode: 388   reward: 83
# episode: 389   reward: 79
# episode: 390   reward: 75
# episode: 391   reward: 71
# episode: 392   reward: 68
# episode: 393   reward: 64
# episode: 394   reward: 61
# episode: 395   reward: 58
# episode: 396   reward: 55
# episode: 397   reward: 53
# episode: 398   reward: 51
# episode: 399   reward: 48
# episode: 400   reward: 46
# episode: 401   reward: 44
# episode: 402   reward: 42
# episode: 403   reward: 40
# episode: 404   reward: 38
# episode: 405   reward: 36
# episode: 406   reward: 34
# episode: 407   reward: 32
# episode: 408   reward: 31
# episode: 409   reward: 30
# episode: 410   reward: 28
# episode: 411   reward: 26
# episode: 412   reward: 25
# episode: 413   reward: 24
# episode: 414   reward: 23
# episode: 415   reward: 23
# episode: 416   reward: 22
# episode: 417   reward: 21
# episode: 418   reward: 20
# episode: 419   reward: 19
# episode: 420   reward: 18
# episode: 421   reward: 17
# episode: 422   reward: 16
# episode: 423   reward: 15
# episode: 424   reward: 14
# episode: 425   reward: 13
# episode: 426   reward: 12
# episode: 427   reward: 11
# episode: 428   reward: 10
# episode: 429   reward: 10
# episode: 430   reward: 9
# episode: 431   reward: 8
# episode: 432   reward: 8
# episode: 433   reward: 7
# episode: 434   reward: 6
# episode: 435   reward: 6
# episode: 436   reward: 6
# episode: 437   reward: 5
# episode: 438   reward: 5
# episode: 439   reward: 5
# episode: 440   reward: 4
# episode: 441   reward: 4
# episode: 442   reward: 4
# episode: 443   reward: 3
# episode: 444   reward: 3
# episode: 445   reward: 3
# episode: 446   reward: 3
# episode: 447   reward: 3
# episode: 448   reward: 3
# episode: 449   reward: 2
# episode: 450   reward: 2
# episode: 451   reward: 2
# episode: 452   reward: 1
# episode: 453   reward: 1
# episode: 454   reward: 1
# episode: 455   reward: 1
# episode: 456   reward: 1
# episode: 457   reward: 1
# episode: 458   reward: 0
# episode: 459   reward: 0
# episode: 460   reward: 0
# episode: 461   reward: 0
# episode: 462   reward: 1
# episode: 463   reward: 1
# episode: 464   reward: 1
# episode: 465   reward: 1
# episode: 466   reward: 1
# episode: 467   reward: 1
# episode: 468   reward: 1
# episode: 469   reward: 1
# episode: 470   reward: 2
# episode: 471   reward: 1
# episode: 472   reward: 1
# episode: 473   reward: 1
# episode: 474   reward: 1
# episode: 475   reward: 1
# episode: 476   reward: 2
# episode: 477   reward: 2
# episode: 478   reward: 2
# episode: 479   reward: 2
# episode: 480   reward: 1
# episode: 481   reward: 1
# episode: 482   reward: 1
# episode: 483   reward: 1
# episode: 484   reward: 1
# episode: 485   reward: 0
# episode: 486   reward: 0
# episode: 487   reward: 0
# episode: 488   reward: 1
# episode: 489   reward: 1
# episode: 490   reward: 1
# episode: 491   reward: 0
# episode: 492   reward: 0
# episode: 493   reward: 1
# episode: 494   reward: 1
# episode: 495   reward: 1
# episode: 496   reward: 1
# episode: 497   reward: 1
# episode: 498   reward: 1
# episode: 499   reward: 2
# episode: 500   reward: 1
# episode: 501   reward: 2
# episode: 502   reward: 2
# episode: 503   reward: 2
# episode: 504   reward: 2
# episode: 505   reward: 2
# episode: 506   reward: 3
# episode: 507   reward: 3
# episode: 508   reward: 3
# episode: 509   reward: 3
# episode: 510   reward: 3
# episode: 511   reward: 3
# episode: 512   reward: 3
# episode: 513   reward: 4
# episode: 514   reward: 4
# episode: 515   reward: 4
# episode: 516   reward: 4
# episode: 517   reward: 5
# episode: 518   reward: 5
# episode: 519   reward: 5
# episode: 520   reward: 5
# episode: 521   reward: 5
# episode: 522   reward: 5
# episode: 523   reward: 5
# episode: 524   reward: 6
# episode: 525   reward: 6
# episode: 526   reward: 6
# episode: 527   reward: 7
# episode: 528   reward: 7
# episode: 529   reward: 8
# episode: 530   reward: 9
# episode: 531   reward: 9
# episode: 532   reward: 13
# episode: 533   reward: 13
# episode: 534   reward: 13
# episode: 535   reward: 14
# episode: 536   reward: 18
# episode: 537   reward: 17
# episode: 538   reward: 16
# episode: 539   reward: 15
# episode: 540   reward: 14
# episode: 541   reward: 14
# episode: 542   reward: 13
# episode: 543   reward: 14
# episode: 544   reward: 15
# episode: 545   reward: 17
# episode: 546   reward: 23
# episode: 547   reward: 28
# episode: 548   reward: 29
# episode: 549   reward: 30
# episode: 550   reward: 33
# episode: 551   reward: 40
# episode: 552   reward: 41
# episode: 553   reward: 46
# episode: 554   reward: 58
# episode: 555   reward: 56
# episode: 556   reward: 56
# episode: 557   reward: 63
# episode: 558   reward: 68
# episode: 559   reward: 77
# episode: 560   reward: 104
# episode: 561   reward: 106
# episode: 562   reward: 102
# episode: 563   reward: 99
# episode: 564   reward: 99
# episode: 565   reward: 99
# episode: 566   reward: 100
# episode: 567   reward: 101
# episode: 568   reward: 103
# episode: 569   reward: 106
# episode: 570   reward: 109
# episode: 571   reward: 111
# episode: 572   reward: 114
# episode: 573   reward: 118
# episode: 574   reward: 118
# episode: 575   reward: 120
# episode: 576   reward: 118
# episode: 577   reward: 119
# episode: 578   reward: 118
# episode: 579   reward: 117
# episode: 580   reward: 116
# episode: 581   reward: 116
# episode: 582   reward: 116
# episode: 583   reward: 116
# episode: 584   reward: 115
# episode: 585   reward: 115
# episode: 586   reward: 118
# episode: 587   reward: 118
# episode: 588   reward: 117
# episode: 589   reward: 117
# episode: 590   reward: 116
# episode: 591   reward: 115
# episode: 592   reward: 113
# episode: 593   reward: 109
# episode: 594   reward: 105
# episode: 595   reward: 100
# episode: 596   reward: 98
# episode: 597   reward: 98
# episode: 598   reward: 97
# episode: 599   reward: 98
# episode: 600   reward: 99
# episode: 601   reward: 100
# episode: 602   reward: 103
# episode: 603   reward: 103
# episode: 604   reward: 103
# episode: 605   reward: 106
# episode: 606   reward: 107
# episode: 607   reward: 108
# episode: 608   reward: 107
# episode: 609   reward: 106
# episode: 610   reward: 104
# episode: 611   reward: 104
# episode: 612   reward: 104
# episode: 613   reward: 104
# episode: 614   reward: 104
# episode: 615   reward: 105
# episode: 616   reward: 108
# episode: 617   reward: 112
# episode: 618   reward: 116
# episode: 619   reward: 121
# episode: 620   reward: 122
# episode: 621   reward: 124
# episode: 622   reward: 123
# episode: 623   reward: 122
# episode: 624   reward: 122
# episode: 625   reward: 121
# episode: 626   reward: 120
# episode: 627   reward: 119
# episode: 628   reward: 117
# episode: 629   reward: 116
# episode: 630   reward: 115
# episode: 631   reward: 115
# episode: 632   reward: 116
# episode: 633   reward: 117
# episode: 634   reward: 118
# episode: 635   reward: 118
# episode: 636   reward: 117
# episode: 637   reward: 117
# episode: 638   reward: 116
# episode: 639   reward: 117
# episode: 640   reward: 119
# episode: 641   reward: 119
# episode: 642   reward: 119
# episode: 643   reward: 119
# episode: 644   reward: 118
# episode: 645   reward: 117
# episode: 646   reward: 118
# episode: 647   reward: 118
# episode: 648   reward: 116
# episode: 649   reward: 115
# episode: 650   reward: 111
# episode: 651   reward: 109
# episode: 652   reward: 108
# episode: 653   reward: 114
# episode: 654   reward: 114
# episode: 655   reward: 111
# episode: 656   reward: 110
# episode: 657   reward: 112
# episode: 658   reward: 122
# episode: 659   reward: 122
# episode: 660   reward: 138
# episode: 661   reward: 153
# episode: 662   reward: 166
# episode: 663   reward: 161
# episode: 664   reward: 156
# episode: 665   reward: 154
# episode: 666   reward: 153
# episode: 667   reward: 153
# episode: 668   reward: 150
# episode: 669   reward: 146
# episode: 670   reward: 142
# episode: 671   reward: 137
# episode: 672   reward: 136
# episode: 673   reward: 137
# episode: 674   reward: 151
# episode: 675   reward: 152
# episode: 676   reward: 150
# episode: 677   reward: 146
# episode: 678   reward: 143
# episode: 679   reward: 143
# episode: 680   reward: 146
# episode: 681   reward: 148
# episode: 682   reward: 148
# episode: 683   reward: 147
# episode: 684   reward: 146
# episode: 685   reward: 150
# episode: 686   reward: 154
# episode: 687   reward: 155
# episode: 688   reward: 150
# episode: 689   reward: 147
# episode: 690   reward: 145
# episode: 691   reward: 144
# episode: 692   reward: 150
# episode: 693   reward: 154
# episode: 694   reward: 155
# episode: 695   reward: 157
# episode: 696   reward: 168
# episode: 697   reward: 169
# episode: 698   reward: 171
# episode: 699   reward: 170
# episode: 700   reward: 162
# episode: 701   reward: 154
# episode: 702   reward: 146
# episode: 703   reward: 139
# episode: 704   reward: 133
# episode: 705   reward: 139
# episode: 706   reward: 139
# episode: 707   reward: 138
# episode: 708   reward: 136
# episode: 709   reward: 134
# episode: 710   reward: 129
# episode: 711   reward: 125
# episode: 712   reward: 121
# episode: 713   reward: 115
# episode: 714   reward: 110
# episode: 715   reward: 106
# episode: 716   reward: 105
# episode: 717   reward: 104
# episode: 718   reward: 104
# episode: 719   reward: 103
# episode: 720   reward: 103
# episode: 721   reward: 105
# episode: 722   reward: 105
# episode: 723   reward: 104
# episode: 724   reward: 104
# episode: 725   reward: 103
# episode: 726   reward: 102
# episode: 727   reward: 102
# episode: 728   reward: 103
# episode: 729   reward: 107
# episode: 730   reward: 108
# episode: 731   reward: 109
# episode: 732   reward: 109
# episode: 733   reward: 109
# episode: 734   reward: 110
# episode: 735   reward: 108
# episode: 736   reward: 108
# episode: 737   reward: 107
# episode: 738   reward: 106
# episode: 739   reward: 106
# episode: 740   reward: 107
# episode: 741   reward: 107
# episode: 742   reward: 105
# episode: 743   reward: 104
# episode: 744   reward: 101
# episode: 745   reward: 102
# episode: 746   reward: 105
# episode: 747   reward: 106
# episode: 748   reward: 111
# episode: 749   reward: 115
# episode: 750   reward: 117
# episode: 751   reward: 117
# episode: 752   reward: 112
# episode: 753   reward: 108
# episode: 754   reward: 106
# episode: 755   reward: 106
# episode: 756   reward: 111
# episode: 757   reward: 110
# episode: 758   reward: 107
# episode: 759   reward: 108
# episode: 760   reward: 107
# episode: 761   reward: 106
# episode: 762   reward: 104
# episode: 763   reward: 100
# episode: 764   reward: 97
# episode: 765   reward: 93
# episode: 766   reward: 93
# episode: 767   reward: 94
# episode: 768   reward: 93
# episode: 769   reward: 94
# episode: 770   reward: 94
# episode: 771   reward: 95
# episode: 772   reward: 97
# episode: 773   reward: 97
# episode: 774   reward: 99
# episode: 775   reward: 100
# episode: 776   reward: 104
# episode: 777   reward: 115
# episode: 778   reward: 124
# episode: 779   reward: 124
# episode: 780   reward: 123
# episode: 781   reward: 121
# episode: 782   reward: 120
# episode: 783   reward: 119
# episode: 784   reward: 117
# episode: 785   reward: 113
# episode: 786   reward: 110
# episode: 787   reward: 109
# episode: 788   reward: 110
# episode: 789   reward: 111
# episode: 790   reward: 115
# episode: 791   reward: 118
# episode: 792   reward: 119
# episode: 793   reward: 125
# episode: 794   reward: 128
# episode: 795   reward: 131
# episode: 796   reward: 137
# episode: 797   reward: 136
# episode: 798   reward: 135
# episode: 799   reward: 134
# episode: 800   reward: 134
# episode: 801   reward: 136
# episode: 802   reward: 136
# episode: 803   reward: 138
# episode: 804   reward: 139
# episode: 805   reward: 138
# episode: 806   reward: 138
# episode: 807   reward: 138
# episode: 808   reward: 137
# episode: 809   reward: 137
# episode: 810   reward: 136
# episode: 811   reward: 134
# episode: 812   reward: 130
# episode: 813   reward: 130
# episode: 814   reward: 130
# episode: 815   reward: 129
# episode: 816   reward: 129
# episode: 817   reward: 128
# episode: 818   reward: 130
# episode: 819   reward: 130
# episode: 820   reward: 139
# episode: 821   reward: 143
# episode: 822   reward: 146
# episode: 823   reward: 146
# episode: 824   reward: 143
# episode: 825   reward: 140
# episode: 826   reward: 138
# episode: 827   reward: 140
# episode: 828   reward: 137
# episode: 829   reward: 135
# episode: 830   reward: 133
# episode: 831   reward: 132
# episode: 832   reward: 133
# episode: 833   reward: 131
# episode: 834   reward: 132
# episode: 835   reward: 134
# episode: 836   reward: 133
# episode: 837   reward: 133
# episode: 838   reward: 135
# episode: 839   reward: 137
# episode: 840   reward: 143
# episode: 841   reward: 142
# episode: 842   reward: 141
# episode: 843   reward: 142
# episode: 844   reward: 145
# episode: 845   reward: 146
# episode: 846   reward: 148
# episode: 847   reward: 152
# episode: 848   reward: 154
# episode: 849   reward: 154
# episode: 850   reward: 152
# episode: 851   reward: 146
# episode: 852   reward: 141
# episode: 853   reward: 139
# episode: 854   reward: 134
# episode: 855   reward: 129
# episode: 856   reward: 126
# episode: 857   reward: 124
# episode: 858   reward: 121
# episode: 859   reward: 120
# episode: 860   reward: 118
# episode: 861   reward: 117
# episode: 862   reward: 117
# episode: 863   reward: 117
# episode: 864   reward: 118
# episode: 865   reward: 117
# episode: 866   reward: 117
# episode: 867   reward: 116
# episode: 868   reward: 116
# episode: 869   reward: 116
# episode: 870   reward: 115
# episode: 871   reward: 116
# episode: 872   reward: 116
# episode: 873   reward: 117
# episode: 874   reward: 116
# episode: 875   reward: 118
# episode: 876   reward: 122
# episode: 877   reward: 123
# episode: 878   reward: 125
# episode: 879   reward: 125
# episode: 880   reward: 126
# episode: 881   reward: 127
# episode: 882   reward: 131
# episode: 883   reward: 135
# episode: 884   reward: 141
# episode: 885   reward: 165
# episode: 886   reward: 175
# episode: 887   reward: 178
# episode: 888   reward: 181
# episode: 889   reward: 182
# episode: 890   reward: 179
# episode: 891   reward: 177
# episode: 892   reward: 175
# episode: 893   reward: 173
# episode: 894   reward: 170
# episode: 895   reward: 170
# episode: 896   reward: 174
# episode: 897   reward: 177
# episode: 898   reward: 175
# episode: 899   reward: 172
# episode: 900   reward: 169
# episode: 901   reward: 166
# episode: 902   reward: 165
# episode: 903   reward: 163
# episode: 904   reward: 163
# episode: 905   reward: 161
# episode: 906   reward: 159
# episode: 907   reward: 156
# episode: 908   reward: 153
# episode: 909   reward: 153
# episode: 910   reward: 151
# episode: 911   reward: 148
# episode: 912   reward: 146
# episode: 913   reward: 141
# episode: 914   reward: 137
# episode: 915   reward: 135
# episode: 916   reward: 133
# episode: 917   reward: 131
# episode: 918   reward: 128
# episode: 919   reward: 126
# episode: 920   reward: 123
# episode: 921   reward: 123
# episode: 922   reward: 122
# episode: 923   reward: 122
# episode: 924   reward: 121
# episode: 925   reward: 119
# episode: 926   reward: 118
# episode: 927   reward: 118
# episode: 928   reward: 118
# episode: 929   reward: 118
# episode: 930   reward: 118
# episode: 931   reward: 118
# episode: 932   reward: 118
# episode: 933   reward: 118
# episode: 934   reward: 119
# episode: 935   reward: 118
# episode: 936   reward: 117
# episode: 937   reward: 115
# episode: 938   reward: 115
# episode: 939   reward: 115
# episode: 940   reward: 114
# episode: 941   reward: 113
# episode: 942   reward: 112
# episode: 943   reward: 112
# episode: 944   reward: 112
# episode: 945   reward: 113
# episode: 946   reward: 113
# episode: 947   reward: 112
# episode: 948   reward: 113
# episode: 949   reward: 113
# episode: 950   reward: 114
# episode: 951   reward: 118
# episode: 952   reward: 126
# episode: 953   reward: 129
# episode: 954   reward: 130
# episode: 955   reward: 130
# episode: 956   reward: 131
# episode: 957   reward: 131
# episode: 958   reward: 132
# episode: 959   reward: 133
# episode: 960   reward: 136
# episode: 961   reward: 137
# episode: 962   reward: 136
# episode: 963   reward: 136
# episode: 964   reward: 135
# episode: 965   reward: 133
# episode: 966   reward: 131
# episode: 967   reward: 130
# episode: 968   reward: 126
# episode: 969   reward: 123
# episode: 970   reward: 122
# episode: 971   reward: 122
# episode: 972   reward: 121
# episode: 973   reward: 122
# episode: 974   reward: 121
# episode: 975   reward: 120
# episode: 976   reward: 120
# episode: 977   reward: 118
# episode: 978   reward: 117
# episode: 979   reward: 115
# episode: 980   reward: 115
# episode: 981   reward: 114
# episode: 982   reward: 114
# episode: 983   reward: 114
# episode: 984   reward: 114
# episode: 985   reward: 113
# episode: 986   reward: 113
# episode: 987   reward: 113
# episode: 988   reward: 113
# episode: 989   reward: 114
# episode: 990   reward: 116
# episode: 991   reward: 118
# episode: 992   reward: 121
# episode: 993   reward: 123
# episode: 994   reward: 124
# episode: 995   reward: 125
# episode: 996   reward: 124
# episode: 997   reward: 122
# episode: 998   reward: 121
# episode: 999   reward: 120

# %% [markdown]
# https://www.jianshu.com/p/25c09ae3d206

# %% [markdown]
# # D4PG

# %% [markdown]
# https://www.linkresearcher.com/theses/c9789137-8f12-4ff8-9ff4-48d21145b09c
#
# https://github.com/deepmind/acme
#
# https://github.com/deepmind/acme/blob/master/docs/index.md
#
# https://github.com/deepmind/acme/blob/master/examples/quickstart.ipynb
#
# https://zhkmxx9302013.github.io/post/dad17569.html
